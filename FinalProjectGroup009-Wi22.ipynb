# %% [markdown]
# ## Our Group Video and Explanation
#
# [Link to the Video](https://drive.google.com/file/d/1HOMzSdJsctX_KxDoklN7Ne-EltVHQdoF/view?usp=sharing)

# %% [markdown]
# # COGS 108 - The COVID-19 Pandemic and its Possible Effects on Air Quality and Traffic

# %% [markdown]
# ## Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public. (Note that student names will be included (but PIDs will be scraped from any groups who include their PIDs).
#
# * [X] YES - make available
# * [  ] NO - keep private

# %% [markdown]
# # Overview

# %% [markdown]
# Through the COVID-19 Pandemic, there have been numerous speculations that Air Quality has improved. Our group decided to conduct our project on the topic of Air Quality (Measured in AQI) and how different factors could have influenced a positive change since the start of COVID-19. We looked at the California Counties to do our analysis. We chose the topics of Traffic (Measured in AADT) and Gasoline Price Sales to see if there was any relationship with an increase/decrease in Air Quality. Upon analysis, we concluded that there was no significant change through COVID-19 on Air Quality. This could be because of several confounding variables such as work fields (Stay-At-Home vs. Commuting) and County location (the others we did not choose to focus on).

# %% [markdown]
# ## Names
#
# - Ava Hamedi
# - Marc Mendoza
# - Jonathan Park
# - Daniel Renteria
# - Siena Rivera

# %% [markdown]
# <a id='research_question'></a>
# # Research Question

# %% [markdown]
# Did California Air Quality significantly improve in different areas due to the COVID-19 Pandemic and the change in car traffic volume?

# %% [markdown]
# <a id='background'></a>
#
# ## Background & Prior Work

# %% [markdown]
# As a society we have all been incredibly affected by the COVID-19 Pandemic, our group thought it would be interesting to check the differences in Air Quality from (2011-2022) specifically in the State of California due to the pandemic and the change in the car traffic volume. Since Air Quality affects every single creature on this planet earth, we want to understand how the COVID-19 pandemic affected the quality of the air we breathe every day. By narrowing our region and time down, we should be able to find information and data to help provide a better conclusion to our posed Research Question. As a collective, we agreed that this project could provide information for society to learn from.
#
# At the end of 2019, governments across the world have issued stay-at-home lockdown orders to help reduce the number of COVID-19 cases.  Consequently, the car traffic volume has significantly decreased since many companies and manufacturers switched to remote work or were closed during the pandemic, a lot of people stayed home due to the fact that some of them decided to not work for a while, and some did their job online. Similarly, all schools, colleges, and universities switched to remote instruction. One of the positive impacts of remote jobs and instruction is less commuting to work and school, and therefore less carbon pollution in the air. “Remote working means fewer people are on the roads. As mentioned, the transport sector is among the number one producers of greenhouse gases. When people work from home, it means less fossil fuel combustion and better air quality”[<sup>1</sup>](#fn1)
#
# Car traffic has a significant role in air pollution. “In urban areas, traffic is one of the major sources of air pollutants. The mixture of vehicle exhausts, secondary pollutants formed in the atmosphere, evaporative emissions from vehicles, and non-combustion emissions (e.g., road dust, tire wear) is referred to as traffic-related air pollution (TRAP)” [<sup>2</sup>](#fn1)
#
# Based on this, we hypothesize that the COVID-19 pandemic had a positive impact on air quality in the state of California.
#
# Air quality is a major factor when it comes to health, and air pollution is a risk to health. Breathing clean air will decrease the number of diseases like heart diseases, stroke, asthma, and lung cancer so knowing what affects the quality of air is important. Across the world, life has incredibly changed due to COVID-19 and the stressors the pandemic has put on everyone. In regards to COVID-19, there are many variables that could be affecting air quality, but our group focuses on car traffic and how its change affected air quality.
#
#
# **What has already been done on this topic?**
#
#
# Several studies have been done across the world that have looked at the overall changes in air quality since COVID-19. These studies show that air quality has improved during the pandemic.
# These studies show that air pollutants like NO2 and PM2.5 have significantly decreased during the pandemic and therefore improved the quality of the air. “Before stay-at-home orders were issued March 16, Zhu said, the EPA’s Air Quality Index, which incorporates multiple air pollutants, including NO2 and PM2.5 (fine particulate matter), was about 60, or in the “moderate” category. Since then, it has improved by about 20 percent and recorded the longest stretch of “good” air quality in March seen since at least 1995” [<sup>3</sup>](#fn1)
#
# Another study called Effect of COVID-19 on air quality and pollution in different countries, states that the spread of COVID-19 and the lockdown led to a decrease in pollutants levels in the air and therefore improved air quality in industrial countries. [<sup>4</sup>](#fn1)
#
# Another study called 2020 COVID-19 lockdown and the impacts on air quality with emphasis on urban, suburban and rural zones.   This study shows an improvement in the quality of the air in different areas like rural and urban across the countries. [<sup>5</sup>](#fn1)
#
#  One study is Air Quality Across Countries in Covid-19 which includes different countries around the world and is for the years 2020-2021.[<sup>6</sup>](#fn1)
# Another study is called Breathe India: COVID-19 effect on Pollution which only studied lockdown effect in India[<sup>7</sup>](#fn1)
#
# Several studies have been done about air quality during the COVID-19 pandemic, However, our group wanted to specialize in a smaller portion and just focus on the State of California.
#
#
#
#
#
#
#  [<sup id="fn1">1</sup>](#fn1-back) [Remote Work through Climate Change](https://emagazine.com/the-impact-of-remote-work-on-climate-change/)<br>
#
#  [<sup id="fn1">2</sup>](#fn1-back) [ Human health effects of traffic-related air pollution (TRAP): a scoping review protocol](https://systematicreviewsjournal.biomedcentral.com/articles/10.1186/s13643-019-1106-5#:~:text=In%20urban%20areas%2C%20traffic%20is,related%20air%20pollution%20(TRAP).)
# <br>
#
#  [<sup id="fn1">3</sup>](#fn1-back) [ The silver lining to coronavirus lockdowns: Air quality is improving](https://www.washingtonpost.com/weather/2020/04/09/air-quality-improving-coronavirus/)<br>
#
#
#  [<sup id="fn1">4</sup>](#fn1-back) [ Effect of COVID-19 on air quality and pollution in different countries](https://pubmed.ncbi.nlm.nih.gov/33816115/#:~:text=Results%3A%20After%20the%20disease%20spread,and%20agreements%20could%20not%20reach)<br>
#
#
#
#  [<sup id="fn1">5</sup>](#fn1-back) [2020 COVID-19 lockdown and the impacts on air quality with emphasis on urban, suburban and rural zones](https://www.nature.com/articles/s41598-021-99491-7)<br>
#
#
# [<sup id="fn1">6</sup>](#fn1-back) [Air Quality Across Countries in COVID-19](https://www.kaggle.com/aestheteaman01/air-quality-across-countries-in-covid19)<br>
#
# [<sup id="fn1">7</sup>](#fn1-back) [ Breathe India: COVID-19 effect on Pollution](https://www.kaggle.com/parulpandey/breathe-india-covid-19-effect-on-pollution)<br>

# %% [markdown]
# # Hypothesis

# %% [markdown]
# *We hypothesize that COVID-19 has had an overall good effect from 2020-2022 on Air Quality based on AQI (Air Quality Index). We think that the pandemic has led to more WFH (work-from-home) and remote opportunities for the general population of California, thus changing the amount of air pollution caused by a reduction in car traffic via commuting. We acknowledge that there may be some confounding variables including regional industries, population per capita, and lockdown restrictions*

# %% [markdown]
# # Dataset(s)

# %% [markdown]
# ### Main Datasets
#
# - **Annual Air Quality by County**
#   - **Name:** annual_aqi_by_county_YEAR.csv
#   - **Shape/Size of OG Dataset:** Shape:  (999 (Depends on Year), 19) Size:  18981
#   - **Shape/Size of Cleaned Dataset:** Shape:  (640, 6) Size:  3840
#   - [Link to the Dataset](https://aqs.epa.gov/aqsweb/airdata/download_files.html#Annual)
#   - **Description:** This dataset contains data and information on Annual Summary of Air Quality through years before 2000 until today. All Data use AQI (Air Quality Index) when applicable. The Measurement AQI is calculated based on the average concentration of a particular pollutant measured over a standard time interval (24 hours for most pollutants, 8 hours for carbon monoxide and ozone). We will be using this dataset to help understand and show the trend of Air Quality throughout years 2007 until today. This way, we can get a trend of how AQI has changed over the years before and through COVID-19.
#   - **Source:** EPA: AirData<br>
# <br>
# - **Annual Average Daily Traffic (AADT) Volumes (1)**
#   - **Name:** traffic_volumes_YEAR.csv
#   - **Shape/Size of OG Dataset:** Shape:  (7253 (Depends on Year), 11) Size:  79783
#   - **Shape/Size of Cleaned Dataset:** Shape:  (58, 4) Size:  232
#   - [Link to the Dataset](https://dot.ca.gov/programs/traffic-operations/census)
#   - **Description:** In addition to Air Quality, our team wanted to look into the relationship between Air Quality and Car and Vehicular Traffic. This dataset contains data and information on Annual Average Daily Traffic Volumes through years 2017 until 2022. This and the following Datasets are the same kind of data but with different years. We will be using this dataset to help understand the average amount of Annual daily traffic through the California area. Although this dataset is more narrow, this will help us have a more narrow scope of information. In comparison to the one below which is the former years. In addition to gathering and cleaning this dataset, we will also be computing the average (mean) of the (Back and Forward Traffic) columns.
#   - **Source:** AQICN.org<br>
#   <br>
# - **Annual Average Daily Traffic (AADT) Volumes (2)**
#   - **Name:** traffic_volumes_YEAR.csv
#   - **Shape/Size of OG Dataset:** Shape:  (6958 (Depends on Year), 11) Size:  76538
#   - **Shape/Size of Cleaned Dataset:** Shape:  (58, 4) Size:  232
#   - [Link to the Dataset](https://data.ca.gov/dataset/fb62fd37-38e5-40a5-89d1-cb58ae12f244/resource/0f021a84-ded0-488c-93b5-f331759ad9fd/download/aadt_2007-2017_shapefiles.gdb.zip)
#   - **Description:** This dataset contains data and information on Annual Average Daily Traffic Volumes through years 2007 until 2017. This and the former Datasets are the same kind of data but with different years. We will be using this dataset to help understand the average amount of Annual daily traffic through the California area. This dataset is more diverse, with over 10 years of data and information for our group to use, this will help us have a more wide scope of information. In addition to gathering and cleaning this  dataset, we will also be computing the average (mean) of the (Back and Forward Traffic) columns.
#   - **Source:** AQICN.org<br>
# <br>
# - **Annual Gasoline Sales by City**
#   - **Name:** gas_sales_by_city.csv
#   - **Shape/Size of OG Dataset:** Shape:  (373, 12) Size:  4476
#   - **Shape/Size of Cleaned Dataset:** Shape:  (372, 11) Size:  4092
#   - [Link to the Dataset](https://www.energy.ca.gov/media/5869)
#   - **Description:** The chosen dataset contains data and information on Annual Gasoline Sales Volumes per City throughout the years 2010 until 2020. We will be cleaning the data and only provide data through years 2011 until 2020 to fit our research question time frame. We will be using this dataset to help understand the usage of gasoline throughout California, and use this to find a correlation to the Air Quality throughout California. Although the data is relatively clean, there are some changes we would like to make to make it easier to understand and work with. Since this dataset has the perfect time frame relative to what we are researching, it will provide our group the 10 years of data necessary to find meaningful relationships. Through this, we can get an idea of how Gasoline Sales Data has changed over the years prior to and during the COVID-19 pandemic, and how this has ultimately affected the AQI throughout California.
#   -**Source:** CEC: energy.ca.gov <br>
#
# <br>
#
#
# **Combining Data**: The datasets we have chosen will be combined and subsequently analyzed to give a measure of the overall relationship between Traffic, Air Quality, and Gasoline usage. From there, we want to look further into the addition of the COVID-19 Pandemic. Our team will be analyzing the causal relationship between the effects of COVID-19 on Air Quality stemming from a change in Car and Vehicular Traffic as well as a change in Gasoline sales. All of our information will be combined into one, larger dataset for the California Area. To answer our Research Question, our main priority is getting all of our data cleaned and ready for analysis. Throughout our cleaning process, it was easy to concatenate the dataframes since the datasets had the same columns.

# %% [markdown]
# # Setup

# %%
# First make sure to have all packages installed on device (pip install pandas, numpy, seaborn, matplotlib, and etc)
# import all packages after installing pip
import pandas as pd
import numpy as np
import seaborn as sns
sns.set(font_scale=2, style="white")
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.style as style
import geopandas as gpd
import pyproj as pyproj
import scipy.stats as stats
from scipy.stats import normaltest, ttest_ind
import patsy
import statsmodels.api as sm
import functools
# Our Warnings when importing code will make it harder to concentrate on what is important
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Table of Contents
#
# - Air Quality in various regions
# - Car Traffic
# - Gasoline Consumption

# %% [markdown]
# ## Air Quality (AQI) Data
#
# ### I. Annual Air Quality (AQI) by County
# First we will focus on the Air Quality (AQI) Data given to the team by the EPA. These dataset contained information for the years of 2010-2021. We only want to focus on years 2010-2021, so we will be removing data that does not fit into our timeline. All Data use AQI (Air Quality Index). The Measurement AQI is calculated based on the average concentration of a particular pollutant measured over a standard time interval (24 hours for most pollutants, 8 hours for carbon monoxide and ozone). We will be using this dataset to help understand and show the trend of Air Quality throughout years 2010 until today. This way, we can get a trend of how AQI has changed over the years before and through COVID-19.

# %%
#importing data
aqi_county_path = ['datasets/annual_aqi_by_county_2010.csv', 
                 'datasets/annual_aqi_by_county_2011.csv', 
                 'datasets/annual_aqi_by_county_2012.csv', 
                 'datasets/annual_aqi_by_county_2013.csv', 
                 'datasets/annual_aqi_by_county_2014.csv', 
                 'datasets/annual_aqi_by_county_2015.csv', 
                 'datasets/annual_aqi_by_county_2016.csv', 
                 'datasets/annual_aqi_by_county_2017.csv', 
                 'datasets/annual_aqi_by_county_2018.csv',
                 'datasets/annual_aqi_by_county_2019.csv', 
                 'datasets/annual_aqi_by_county_2020.csv', 
                 'datasets/annual_aqi_by_county_2021.csv']

# %%
#parsing data
aqi_county_frames = []
for path in aqi_county_path:
    aqi_county_frames.append(pd.read_csv(path))
aqi_county = pd.concat(aqi_county_frames, ignore_index = True)

# %%
#columns to remove from files
aqi_county_bad = ['Days with AQI', 'Good Days', 'Moderate Days', 'Unhealthy for Sensitive Groups Days',
                  'Unhealthy Days', 'Very Unhealthy Days', 'Hazardous Days', 'Days CO', 'Days NO2',
                  'Days Ozone', 'Days SO2', 'Days PM2.5', 'Days PM10']

# %%
#dropping columns
aqi_county.drop(aqi_county_bad, axis = 1, inplace = True)
#dropping rows
aqi_county_CA = aqi_county[aqi_county['State']=='California']
#resetting index
aqi_county_CA.reset_index(drop=True, inplace = True)

aqi_county_CA.to_pickle('datasets/pickled_aqi.pkl')

aqi_county_CA.head()
# Out:
#         State     County  Year  Max AQI  90th Percentile AQI  Median AQI
# 0  California    Alameda  2010      179                   68          43
# 1  California     Amador  2010      151                   64          35
# 2  California      Butte  2010      126                   84          47
# 3  California  Calaveras  2010      154                   84          41
# 4  California     Colusa  2010      119                   49          38

# %% [markdown]
# #### Columns
# - State: The state in which the Air Quality was measured. In our case, it is only California.
# - County: The county (of California) in which the Air Quality was measured.
# - Year: The year the Air Quality was measured.
# - Max AQI: The maximum AQI (worst air quality) that year.
# - 90th Percentile AQI: The 90th percentile AQI value that year.
# - Median AQI: The median AQI that year.

# %% [markdown]
# ## Traffic Data
#
# ### II. Annual Daily Traffic Data
# In addition to Air Quality, our team wanted to look into the relationship between Air Quality and Car and Vehicular Traffic. The chosen datasets contain data and information on Annual Average Daily Traffic Volumes through years 2007 until 2020. We will be using this dataset to help understand the average amount of Annual daily traffic through the state of California. We found this information via data.ca.gov, through the data that CalTrans gathers on traffic volumes. We only want to focus on a more narrow area and scope, so we will be cleaning up the datasets to help provide us with the best information. This way, we can also get a trend of how Annual Daily Traffic Data has changed over the years before and through COVID-19. We will also be showcasing the data in ways that are most intuitive. We will eventually be  grouping and taking the average (mean) of the (Back and Forward Traffic) columns. We will also only look at the AADT, the annual average, so we will drop all columns pertaining to daily measured peaks or monthly measures.

# %%
#importing data               
traffic_path_1 = ['datasets/traffic_volumes_2007.csv',
               'datasets/traffic_volumes_2008.csv',
               'datasets/traffic_volumes_2009.csv',
               'datasets/traffic_volumes_2010.csv',
               'datasets/traffic_volumes_2011.csv',
               'datasets/traffic_volumes_2012.csv',
               'datasets/traffic_volumes_2013.csv',
               'datasets/traffic_volumes_2014.csv',
               'datasets/traffic_volumes_2015.csv',
               'datasets/traffic_volumes_2016.csv',
               'datasets/traffic_volumes_2017.csv']
traffic_path_2 = ['datasets/traffic_volumes_2018.csv',
               'datasets/traffic_volumes_2019.csv']
traffic_path_3 = 'datasets/traffic_volumes_2020.csv'

# %%
#parsing data
traffic_frames_1 = []
index = 2007
for path in traffic_path_1:
    temp = pd.read_csv(path)
    temp['Year'] = index
    traffic_frames_1.append(temp)
    index += 1
traffic_1 = pd.concat(traffic_frames_1, ignore_index= True)

traffic_frames_2 = []
for path in traffic_path_2:
    temp = pd.read_csv(path)
    temp['Year'] = index
    traffic_frames_2.append(temp)
    index += 1
traffic_2 = pd.concat(traffic_frames_2, ignore_index= True)

traffic_3 = pd.read_csv(traffic_path_3)
traffic_3['Year'] = index

# %%
#columns to keep from files
traffic_keep_1 = ['County', 'Back_AADT', 'Ahead_AADT', 'Year']
traffic_keep_2 = ['CNTY', 'BACK_AADT', 'AHEAD_AADT', 'Year']
traffic_keep_3 = ['COUNTY', 'BACK_AADT', 'AHEAD_AADT', 'Year']

# %%
#dropping, renaming columns
traffic_1_cond = traffic_1[traffic_keep_1]
traffic_2_cond = traffic_2[traffic_keep_2].rename(columns={'CNTY':'County', 'BACK_AADT':'Back_AADT', 'AHEAD_AADT':'Ahead_AADT'})
traffic_3_cond = traffic_3[traffic_keep_3].rename(columns={'COUNTY':'County', 'BACK_AADT':'Back_AADT', 'AHEAD_AADT':'Ahead_AADT'})

#combining dataframes
traffic_frames_final = [traffic_1_cond, traffic_2_cond, traffic_3_cond]
traffic = pd.concat(traffic_frames_final, ignore_index= True)

#dropping null rows
traffic.dropna(axis=0, inplace= True)

#renaming row values
full_name = {'ALA':'Alameda','ALP':'Alpine','AMA':'Amador','BUT':'Butte', 'CAL':'Calaveras', 'CC':'Contra Costa','COL':'Colusa','DN':'Del Norte','ED':'El Dorado','FRE':'Fresno','GLE':'Glenn','HUM':'Humboldt',
            'IMP':'Imperial','INY':'Inyo','KER':'Kern','KIN':'Kings','LA':'Los Angeles','LAK':'Lake','LAS':'Lassen','MAD':'Madera','MEN':'Mendocino','MER':'Merced','MNO':'Mono','MOD':'Modoc','MON':'Monterey',
            'MPA':'Mariposa','MRN':'Marin','NAP':'Napa','NEV':'Nevada','ORA':'Orange','PLA':'Placer','PLU':'Plumas','RIV':'Riverside','SAC':'Sacramento','SB':'Santa Barbara','SBD':'San Bernardino',
            'SBT':'San Benito','SCL':'Santa Clara','SCR':'Santa Cruz','SD':'San Diego', 'SF': 'San Francisco','SHA':'Shasta','SIE':'Sierra','SIS':'Siskiyou', 'SJ':'San Joaquin', 'SLO': 'San Luis Obispo',
            'SM':'San Mateo','SOL':'Solano','SON':'Sonoma','STA':'Stanislaus','SUT':'Sutter','TEH':'Tehama','TRI':'Trinity','TUL':'Tulare','TUO':'Tuolumne','VEN':'Ventura','YOL':'Yolo','YUB':'Yuba'}
traffic['County'] = traffic['County'].replace(full_name)

# %%
#grouping by county, then adding mean AADT column
traffic_counties = traffic.groupby(['County', 'Year']).sum().reset_index()[1:].reset_index().drop(columns='index')
AADT_mean = (traffic_counties['Back_AADT'] + traffic_counties['Ahead_AADT'])/2
traffic_counties['Mean_AADT'] = AADT_mean
traffic_counties.insert(loc=0, column="State", value="California")
traffic_counties.head()
# Out:
#         State   County  Year   Back_AADT  Ahead_AADT   Mean_AADT
# 0  California  Alameda  2007  24039150.0  22536000.0  23287575.0
# 1  California  Alameda  2008  22928500.0  23130200.0  23029350.0
# 2  California  Alameda  2009  22900450.0  22573900.0  22737175.0
# 3  California  Alameda  2010  14204650.0  13128700.0  13666675.0
# 4  California  Alameda  2011  22901750.0  21337200.0  22119475.0

# %%
california_population = pd.read_csv('datasets/california_population.csv')
traffic_counties_capita = pd.DataFrame(columns = ['State', 'County', 'Year', 'Back_AADT', 'Ahead_AADT', 'Mean_AADT'])
j = 0
k = 2
for i in range(len(traffic_counties)):
    tempCounty = traffic_counties['County'][i]
    tempYear = traffic_counties['Year'][i]
    pop = california_population.loc[j][k]

    traffic_counties_capita.loc[-1] = ['California', tempCounty, tempYear, traffic_counties['Back_AADT'][i]/pop, traffic_counties['Ahead_AADT'][i]/pop, traffic_counties['Mean_AADT'][i]/pop]
    traffic_counties_capita.index = traffic_counties_capita.index + 1
    k += 1
    if k == 16:
        k = 2
        j += 1
traffic_counties_capita.reset_index(drop = True, inplace = True)
traffic_counties_capita.head()
# Out:
#         State   County  Year  Back_AADT  Ahead_AADT  Mean_AADT
# 0  California  Alameda  2007  16.513638   15.481052  15.997345
# 1  California  Alameda  2008  15.521511   15.658052  15.589782
# 2  California  Alameda  2009  15.281851   15.063939  15.172895
# 3  California  Alameda  2010   9.388419    8.677281   9.032850
# 4  California  Alameda  2011  14.959733   13.937747  14.448740

# %% [markdown]
# ### Columns
# - County: California county where the traffic volume was measured.
# - Back_AADT: The total count of vehicles measured at the "back" of a measured road (before traffic light or intersection).
# - Ahead_AADT: The total count of vehicles measured at the "front" of a measured road (past traffic light or intersection).
# - Mean_AADT: The mean of Back_AADT and Ahead_AADT.

# %% [markdown]
# ## Gasoline Sales Data
#
# ### III. Annual Gasoline Sales Data
# In addition to Vehicle Traffic, our team wanted to look into the relationship between Air Quality and Gasoline usage. The chosen dataset contains data and information on Annual Gasoline Sales Volumes per City throughout the years 2010 until 2020, however, we will be cleaning the data and only provide data through years 2011 until 2020. We will be using this dataset to help understand the usage of gasoline throughout California, and use this to find a correlation to the Air Quality. Although the data is relatively clean, there are some changes we would like to make to make it easier to understand and work with. Through this, we can get an idea of how Gasoline Sales Data has changed over the years prior to and during the COVID-19 pandemic, and how this has ultimately affected the AQI throughout California.

# %%
# Import Data
gas_sales = pd.read_csv('datasets/gas_sales_by_city.csv')

# Drop 2010 Column
gas_sales.drop(labels="2010", axis = 1, inplace = True)

#Drop null values (if any)
gas_sales.dropna(axis=0, inplace= True)

# Format City Column
gas_sales['City'] = gas_sales['City'].str.title()
gas_sales.to_pickle('datasets/pickled_gas.pkl')

gas_sales.insert(loc=0, column="State", value="California")
gas_sales.rename(columns={"City":"County"}, inplace=True)
#Chaning the Strings into ints
gas_sales.replace(',' , '', regex=True, inplace=True)
gas_sales[list(gas_sales.columns)[2:]] = gas_sales[list(gas_sales.columns)[2:]].apply(pd.to_numeric, errors='coerce', axis=1)
gas_sales.head()
# Out:
#         State       County       2011       2012       2013       2014  \
# 0  California  Los Angeles  576975774  569572568  513096586  462203720
# 1  California    San Diego  435507017  418994094  350573480  382951006
# 2  California   Sacramento  259938992  260349538  255080126  174054379
# 3  California     San Jose  299816301  292742725  278676054  218224534
# 4  California  Bakersfield  193751205  193930997  178563239  168800299
#
#         2015       2016       2017       2018       2019       2020
# 0  489927305  577624448  597482538  553325286  551182317  434124374
# 1  429738409  458149963  478402573  463772772  454951806  351446047
# 2  255968575  278560889  283805191  264019029  278151293  245128423
# 3  286512916  324059453  318609135  298305348  311325761  234628392
# 4  181022100  221473122  216668139  204619282  204009437  190635868

# %%
# Rename City column to Year before transpose
gas_sales_adjust = gas_sales.rename(columns= {'County': 'Year'})

# Transpose data frame to get City names as columns (more sensible choice to graph)
gas_sales_T = gas_sales_adjust.T
gas_sales_T = gas_sales_T.reset_index()

# Adjust header for simplicity of Dataframe
new_header = gas_sales_T.iloc[1]
gas_sales_T = gas_sales_T[2:] 
gas_sales_T.columns = new_header

# %%
#merge all cities so they belong to a county
city_to_county = {'San Jose':'Santa Clara','Bakersfield': 'Kern', 'Long Beach':'Los Angeles', 'Stockton':'San Joaquin', 'Anaheim':'Orange', 'Chula Vista':'San Diego', 'Corona':'Riverside', 'Fontana': 'San Bernardino',
    'Modesto':'Stanislaus', 'Ontario':'San Bernardino', 'Escondido': 'San Diego','Oakland':'Alameda', 'Roseville':'Placer','Oxnard':'Ventura', 'Santa Rosa':'Sonoma','Santa Ana':'Orange','Elk Grove':'Sacramento',
    'Salinas': 'Monterey','Torrance':'Los Angeles','Irvine':'Orange','Fullerton':'Orange','Huntington Beach':'Orange','Van Nuys':'Los Angeles','Moreno Valley':'Riverside','Temecula':'Riverside',
    'El Cajon':'San Diego','Fremont':'Alameda','Rancho Cucamonga':'San Bernardino','Victorville':'San Bernardino','Garden Grove':'Orange','Hayward':'Alameda','San Leandro':'Alameda','Palmdale':'Los Angeles',
    'Lancaster':'Los Angeles','Fountain Valley':'Orange','South San Francisco':'San Mateo','Tracy':'San Joaquin','Redding':'Shasta','Hesperia':'San Bernardino','Simi Valley':'Ventura','Oceanside':'San Diego',
    'Burbank':'Los Angeles','Vallejo':'Solano','Santa Maria':'Santa Barbara','Pomona':'Los Angeles','Woodland Hills':'Los Angeles','Tustin':'Orange','Vista':'San Diego','Clovis':'Fresno','Hawthorne':'Los Angeles',
    'Whittier':'Los Angeles','Concord':'Contra Costa','Livermore':'Alameda','Norwalk':'Los Angeles','Vacaville':'Solano','Visalia':'Tulare','Carlsbad':'San Diego','Turlock':'Stanislaus',
    'North Hollywood':'Los Angeles','Santa Clarita':'Los Angeles','Murrieta':'Riverside','Lodi':'San Joaquin','Northridge':'Los Angeles','Chino':'San Bernardino','Glendale':'Los Angeles','Chico':'Butte',
    'Perris':'Riverside','Manteca':'San Joaquin','Inglewood':'Los Angeles','Antioch':'Contra Costa','Fairfield':'Solano','La Habra':'Orange','Sunnyvale':'Santa Clara','Folsom':'Sacramento',
    'Lake Elsinore':'Riverside','Richmond':'Contra Costa','Costa Mesa':'Orange','Rancho Cordova':'Sacramento','Laguna Niguel':'Orange','Palm Desert':'Riverside','Redwood City':'San Mateo',
    'Citrus Heights':'Sacramento','Gardena':'Los Angeles','San Marcos':'San Diego','Pacoima':'Los Angeles','Downey':'Los Angeles','Rialto':'San Bernardino','Pasadena':'Los Angeles','West Covina':'Los Angeles',
    'Gilroy':'Santa Clara','Hemet':'Riverside','El Monte':'Los Angeles','Santee':'San Diego','Lakewood':'Los Angeles','Indio':'Riverside','Mission Viejo':'Orange','Azusa':'Los Angeles','Alhambra':'Los Angeles',
    'Compton':'Los Angeles','Culver City':'Los Angeles','Carson':'Los Angeles','La Mesa':'San Diego','Barstow':'San Bernardino','Chino Hills':'San Bernardino','Cypress':'Orange','Monterey Park':'Los Angeles',
    'Woodland':'Yolo','Auburn':'Placer', 'Upland':'San Bernardino','Daly City':'San Mateo','Camarillo':'Ventura','Bellflower':'Los Angeles','Poway':'San Diego','Rocklin':'Placer','Yuba City':'Sutter',
    'Hanford':'Kings','Redlands':'San Bernardino','Spring Valley':'San Diego','Paso Robles':'San Luis Obispo','San Dimas':'Los Angeles','Colton':'San Bernardino','West Sacramento':'Yolo','Castro Valley':'Alameda',
    'South Gate':'Los Angeles','City Of Industry':'Los Angeles','Lake Forest':'Orange','Rohnert Park':'Sonoma','Commerce':'Los Angeles','Thousand Oaks':'Ventura','National City':'San Diego','Eureka':'Humboldt',
    'Walnut Creek':'Contra Costa','Yorba Linda':'San Diego','Campbell':'Santa Clara','Baldwin Park':'Los Angeles','Coachella':'Riverside','Brentwood':'Contra Costa','Highland':'San Bernardino',
    'San Juan Capistrano':'Orange','Novato':'Marin','Westminster':'Orange','Valencia':'Los Angeles','La Puente':'Los Angeles','Pittsburg':'Contra Costa','Glendora':'Los Angeles','Petaluma':'Sonoma',
    'Delano':'Kern','San Rafael':'Marin','Yucaipa':'San Bernardino','Encinitas':'San Diego','Reseda':'Los Angeles','San Clemente':'Orange','Montclair':'San Bernardino','El Centro':'Imperial','Dublin':'Alameda',
    'Sun Valley':'Los Angeles','San Pedro':'Los Angeles','Mill Valley':'Marin','Porterville':'Tulare','Berkeley':'Alameda','Canoga Park':'Los Angeles','Ukiah':'Mendocino','San Jacinto':'Riverside',
    'Chatsworth':'Los Angeles','Pleasanton':'Alameda','La Quinta':'Riverside','Tehachapi':'Kern','Milpitas':'Santa Clara','Norco':'Riverside','Lebec':'Kern','Sylmar':'Los Angeles','Mountain View':'Santa Clara',
    'Pleasant Hill':'Contra Costa','Lynwood':'Los Angeles','San Ramon':'Contra Costa','Apple Valley':'San Bernardino','Paramount':'Los Angeles','Cathedral City':'Riverside','Calexico':'Imperial',
    'Buena Park':'Orange','Grass Valley':'Nevada','Sherman Oaks':'Los Angeles','Santa Monica':'Los Angeles','Morgan Hill':'Santa Clara','Arcadia':'Los Angeles','Atascadero':'San Luis Obispo',
    'Walnut':'Los Angeles', 'Watsonville':'Santa Cruz','Lemoore':'Kings','Brea':'Orange','Palm Springs':'Riverside','Red Bluff':'Tehama','Lompoc':'Santa Barbara','Placentia':'Orange','Marysville':'Yuba',
    'Oakley':'Contra Costa','Dixon':'Solano','Diamond Bar':'Los Angeles','Martinez':'Contra Costa','El Dorado Hills':'El Dorado','Granada Hills':'Los Angeles','Montebello':'Los Angeles','Covina':'Los Angeles',
    'Ripon':'San Joaquin','Pico Rivera':'Los Angeles','Buellton':'Santa Barbara','Lincoln':'Placer','Danville':'Contra Costa','Los Banos':'Merced','Goleta':'Santa Barbara','San Bruno':'San Mateo',
    'Placerville':'El Dorado','Harbor City':'Los Angeles','Newhall':'Santa Clara','Coalinga':'Fresno','Yucca Valley':'San Bernardino','Carmichael':'Sacramento', 'Sanger':'Fresno','Stanton':'Orange',
    'Beaumont':'Riverside','Davis':'Yolo','Moorpark':'Ventura','Menlo Park':'San Mateo','Newport Beach':'Orange','La Mirada':'Los Angeles','Lemon Grove':'San Diego','Lawndale':'Los Angeles',
    'Redondo Beach':'Los Angeles','Canyon Country':'Los Angeles','Huntington Park':'Los Angeles','Hacienda Heights':'Los Angeles','Hollister':'San Benito','Sonora':'Tuolumne','Atwater':'Merced',
    'Laguna Hills':'Orange','Oakdale':'Stanislaus','Mission Hills':'Los Angeles','Desert Hot Springs':'Riverside','Aliso Viejo':'Orange','Bloomington':'San Bernardino','Dana Point':'Orange',
    'Union City':'Alameda','Los Gatos':'Santa Clara','Selma':'Fresno','Lathrop':'San Joaquin','Blythe':'Riverside','Rosemead':'Los Angeles','Patterson':'Stanislaus','Palo Alto':'Santa Clara',
    'Cupertino':'Santa Clara','Castaic':'Los Angeles','South El Monte':'Los Angeles','Lakeside':'San Diego','Anderson':'Shasta','North Highlands':'Sacramento', 'Arroyo Grande':'San Luis Obispo',
    'Lost Hills':'Kern','Cerritos':'Los Angeles','Santa Paula':'Ventura','San Gabriel':'Los Angeles','San Fernando':'Los Angeles','Arvin':'Kern','Corning':'Tehama','Ramona':'San Diego','Firebaugh':'Fresno',
    'Fair Oaks':'Sacramento','Banning':'Riverside', 'Tarzana':'Los Angeles','Rancho Santa Margarita':'Orange','Benicia':'Solano','Bishop':'Inyo','Newbury Park':'Ventura','Newark':'Alameda',
    'La Canada Flintridge':'Los Angeles','Westlake Village':'Los Angeles','Farmersville':'Tulare','Encino':'Los Angeles','Oroville':'Butte','Lomita':'Los Angeles','San Ysidro':'San Diego','Millbrae':'San Mateo',
    'Orland':'Glenn', 'King City':'Monterey','Marina Del Rey':'Los Angeles','Riverbank':'Stanislaus','Wilmington':'Los Angeles','Monrovia':'Los Angeles','Ridgecrest':'Kern','Chowchilla':'Madera',
    'Brawley':'Imperial','Calabasas':'Los Angeles','Belmont':'San Mateo','Santa Fe Springs':'Los Angeles','El Sobrante':'Contra Costa','Malibu':'Los Angeles','Livingston':'Merced','El Segundo':'Los Angeles',
    'Seal Beach':'Orange','Adelanto':'San Bernardino','Imperial Beach':'San Diego','Yreka':'Siskiyou','Sun City':'Riverside','Mojave':'Kern','Studio City':'Los Angeles','Cameron Park':'El Dorado',
    'Cotati':'Sonoma', 'Lindsay':'Tulare','South Lake Tahoe':'El Dorado','Arcata':'Humboldt','Fillmore':'Ventura','Twentynine Palms':'San Bernardino','Del Mar':'San Diego','Corona Del Mar':'Orange',
    'Fortuna':'Humboldt','Lakeport':'Lake','Burlingame':'San Mateo','Reedley':'Fresno','Artesia':'Los Angeles', 'Soledad':'Monterey','Fort Bragg':'Mendocino','Lafayette':'Contra Costa','Willows':'Glenn',
    'Carmel':'Monterey','West Hollywood':'Los Angeles','Taft':'Kern','Willits':'Mendocino','Pismo Beach':'San Luis Obispo','Healdsburg':'Sonoma','Wasco':'Kern', 'Shafter':'Kern',
    'Rancho Palos Verdes':'Los Angeles','Lamont':'Kern','Kingsburg':'Fresno','Carpinteria':'Santa Barbara','Suisun City':'Solano','Susanville':'Lassen','Laguna Beach':'Orange', 'Crescent City':'Del Norte',
    'Fallbrook':'San Diego','Live Oak':'Sutter','San Carlos':'San Mateo','Rowland Heights':'Los Angeles','Jamestown':'Tuolumne','Avenal':'Kings','Paradise':'Butte','Dos Palos':'Merced','Quincy':'Plumas',
    'Angels Camp':'Calaveras', 'Needles':'San Bernardino', 'Ceres':'Stanislaus'}

# %%
#merging all cities into counties
gas_sales_T.rename(columns = city_to_county, inplace = True)
gas_sales_T = gas_sales_T.groupby(gas_sales_T.columns, axis=1,).sum()
gas_sales_T_year = gas_sales_T.pop('Year')
gas_sales_T.insert(0,'Year',gas_sales_T_year)

# %%
#normaling data
gas_sales_T_capita = pd.DataFrame(columns = gas_sales_T.columns)

for i in range(2,12):
    temp_list = []
    year_name = gas_sales_T['Year'][i]
    temp_list.append(year_name)
    for j in range(1, 52):
        county_name = gas_sales_T.columns[j]
        county_gas_sale = gas_sales_T[county_name][i]
        county_row = california_population.index[california_population['County']==county_name].tolist()[0]
        county_pop = california_population[year_name][county_row]
        temp_list.append(county_gas_sale/county_pop)
    gas_sales_T_capita.loc[-1] = temp_list
    gas_sales_T_capita.index = gas_sales_T_capita.index + 1
gas_sales_T_capita.reset_index(drop=True, inplace = True)
gas_sales_T_capita.head()
# Out:
# 1  Year     Alameda       Butte  Calaveras  Contra Costa   Del Norte  \
# 0  2011  296.479507  286.675048  61.958369    272.966716  185.144444
# 1  2012  304.068776  274.210040  37.122099    281.090586  184.293988
# 2  2013  278.440999  262.289566  23.412826    263.298834  144.946443
# 3  2014  204.559410  239.077924  32.922622    213.820766  146.790302
# 4  2015  246.478342  252.691804  42.537979    244.161170  147.461946
#
# 1   El Dorado      Fresno       Glenn    Humboldt  ...      Solano  \
# 0  249.164244  261.512233  397.106075  235.906711  ...  412.964782
# 1  290.079961  260.533346  360.726362  231.635839  ...  420.710367
# 2  252.752447  241.361613  388.920386  264.391217  ...  377.866158
# 3  152.403097  173.291924  394.988742  152.248491  ...  272.447827
# 4  262.874450  247.587570  452.972658  233.697656  ...  370.975857
#
# 1      Sonoma  Stanislaus      Sutter      Tehama      Tulare    Tuolumne  \
# ...

# %% [markdown]
# The units being used to track gasoline sales over the 10 years in the dataset are in 1000 gallon units. There are a total of 11 columns where one is for the City names, and the other ten are for the years 2011 through 2020, the years where gasoline sales were being tracked. There are a total of 372 rows for the cities that actually had gasoline sales data, with their respective gasoline sales per year.

# %% [markdown]
# # Data Analysis & Results

# %% [markdown]
# ## Table of Contents
#
# - Initial Exploratory Data Analysis & Data Visualizations
#   - Car Traffic
#   - Gasoline Consumption
#   - Air Quality in various regions
# - EDA And Data Analysis

# %% [markdown]
# ## Initial Exploratory Data Analysis & Data Visualizations
#
#
# ## Air Quality (AQI) Data
# ### I. Annual Air Quality (AQI) by County
#
# We will be using the former dataset to visualize the Air Quality (AQI) through years 2010-Today

# %%
aqi_county_counts = aqi_county_CA["Median AQI"].value_counts().head(10)
top_10 = aqi_county_counts.index.tolist()
plt.rcParams['figure.dpi'] = 80
sns.set(style="whitegrid", font_scale=1)
sns.set(rc={'figure.figsize':(10,3)})

sns.set_color_codes('muted')
sns.set(style="whitegrid")
top_10df = aqi_county_CA[aqi_county_CA["Median AQI"].isin(top_10)]


county_aqi_plot = sns.barplot(x=aqi_county_CA["County"],y=aqi_county_CA["Median AQI"])
county_aqi_plot.set_ylabel("", fontsize = 15)
county_aqi_plot.set_xlabel("California Counties", fontsize = 15)
county_aqi_plot.set_title("AQI Median Counts by County", fontsize = 20)
ignorethis = county_aqi_plot.set_xticklabels(aqi_county_CA["County"].unique().astype(str), rotation='vertical', fontsize=10)

figure = county_aqi_plot.get_figure()

# %%
shape_x = "./shapefile/california-counties.shx"
map_df = gpd.read_file(shape_x)
map_df.to_crs(pyproj.CRS.from_epsg(4326), inplace=True)

merged = map_df.set_index("County").join(aqi_county_CA.set_index("County"))
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
merged.plot(column='Median AQI',
            cmap='rocket_r',
            linewidth=0.5,
            edgecolor="black",
            legend=True, ax=ax, missing_kwds={
            "color": "lightgrey",
            "label": "Missing values",},)
ax.set_title('Median AQI Counts by California Counties', fontsize=20)
ax.tick_params(left=False, labelleft=False, bottom=False, labelbottom=False)

# %% [markdown]
# Above is the median air quality index by county by 2010 til 2021.
#
# We will choose some counties to see some general patterns in different parts of the state California.

# %% [markdown]
# ## Exploring AQI data by County Visualization

# %%
#setting up our variables
fig = plt.figure()
min_val, max_val = 0.2,.7
n = 3
orig_cmap = plt.cm.copper
colors = orig_cmap(np.linspace(min_val, max_val, n))
cmap = mpl.colors.LinearSegmentedColormap.from_list("mycmap", colors)
selected_counties = ['Los Angeles','San Diego', 'Shasta', 'Santa Cruz', 'Mariposa', 'Sacramento']
#plotting our graphs
for county in selected_counties:
    temp = aqi_county_CA[aqi_county_CA['County'] == county]
    temp.plot(x='Year', rot=45, y=['Max AQI', '90th Percentile AQI', 'Median AQI'],cmap=cmap)
    plt.legend(bbox_to_anchor=(1, 0.5), loc='lower left', prop={'size':15})
    plt.title(county)
    plt.ylabel('count')
    plt.grid(b=False)
    plt.show()

# %%
fh = aqi_county[aqi_county['County'].isin(selected_counties)]
ax = sns.scatterplot(data=fh, x='Year', y='Max AQI', hue='County',palette="rocket")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
ax.set_title('Max AQI in Each County from 2010 to 2020')
# Out:
# Text(0.5, 1.0, 'Max AQI in Each County from 2010 to 2020')

# %% [markdown]
# Above is the max air quality count in these five district from 2010 to 2021.

# %% [markdown]
# # Exploring traffic data by county Visualization

# %%
traffic_counties_counts= traffic_counties['Mean_AADT'].value_counts().head(10)
top_10 = traffic_counties_counts.index.tolist()
plt.rcParams['figure.dpi'] = 80
sns.set(style="whitegrid", font_scale=1)
sns.set(rc={'figure.figsize':(10,3)})

sns.set_color_codes('muted')
sns.set(style="whitegrid")
top_10df = traffic_counties[traffic_counties['Mean_AADT'].isin(top_10)]


traffic_counties_plot = sns.barplot(x=traffic_counties["County"],y=traffic_counties['Mean_AADT'])
traffic_counties_plot.set_ylabel("", fontsize = 15)
traffic_counties_plot.set_xlabel("California Counties", fontsize = 15)
traffic_counties_plot.set_title("Traffic mean Counts by County", fontsize = 20)
ignorethis = traffic_counties_plot.set_xticklabels(traffic_counties["County"].unique().astype(str), rotation='vertical', fontsize=10)

figure1 = traffic_counties_plot.get_figure()

# %% [markdown]
# Above is the average traffic mean by county for the years 2010 to 2020. As shown above we can see that specific counties such as Los Angeles and San Diego have significantly higher traffic mean counts than others, but we will keep this data as it is relevant to our analysis.

# %%
traffic_counties_capita_counts= traffic_counties_capita['Mean_AADT'].value_counts().head(10)
top_10 = traffic_counties_capita_counts.index.tolist()
plt.rcParams['figure.dpi'] = 80
sns.set(style="whitegrid", font_scale=1)
sns.set(rc={'figure.figsize':(10,3)})

sns.set_color_codes('muted')
sns.set(style="whitegrid")
top_10df = traffic_counties_capita[traffic_counties_capita['Mean_AADT'].isin(top_10)]


traffic_counties_capita_plot = sns.barplot(x=traffic_counties_capita["County"],y=traffic_counties_capita['Mean_AADT'])
traffic_counties_capita_plot.set_ylabel("", fontsize = 15)
traffic_counties_capita_plot.set_xlabel("California Counties", fontsize = 15)
traffic_counties_capita_plot.set_title("Traffic mean Counts by County per Capita", fontsize = 20)
ignorethis = traffic_counties_capita_plot.set_xticklabels(traffic_counties_capita["County"].unique().astype(str), rotation='vertical', fontsize=10)

figure1 = traffic_counties_capita_plot.get_figure()

# %% [markdown]
# Above is the Traffic mean count by County per Capita from years 2007 to 2020. As seen above when considering the traffic mean counts per capita, the data is considering the population size of each county therefore outliers in the previous graph (Traffic mean Counts by County) aren't significantly higher than others. Instead counties with high traffic mean counts and lower populations, such as Alpine and Colusa, will be seen as significantly higher than the rest.

# %%
merged = map_df.set_index("County").join(traffic_counties.set_index("County"))
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
merged.plot(column='Mean_AADT',
            cmap='cool',
            linewidth=0.5,
            edgecolor="black",
            legend=True, ax=ax, missing_kwds={
            "color": "lightgrey",
            "label": "Missing values",},)
ax.set_title('Traffic AADT Means by California Counties', fontsize=20)
ax.tick_params(left=False, labelleft=False, bottom=False, labelbottom=False)

# %% [markdown]
# Above is the average traffic count by county in years 2007 through 2020.

# %%
merged = map_df.set_index("County").join(traffic_counties_capita.set_index("County"))
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
merged.plot(column='Mean_AADT',
            cmap='cool',
            linewidth=0.5,
            edgecolor="black",
            legend=True, ax=ax, missing_kwds={
            "color": "lightgrey",
            "label": "Missing values",},)
ax.set_title('Traffic AADT Means by California Counties per Capita', fontsize=20)
ax.tick_params(left=False, labelleft=False, bottom=False, labelbottom=False)

# %% [markdown]
# Above is the average traffic count by county per capita in years 2007 through 2020.

# %% [markdown]
# # Traffic data for the chosen counties

# %% [markdown]
# Below are graphs of the average traffic count from years 2007 to 2020 showing average traffic counts.

# %%
#setting up our variables
orig_cmap = plt.cm.viridis
colors = orig_cmap(np.linspace(min_val, max_val, n))
cmap = mpl.colors.LinearSegmentedColormap.from_list("mycmap", colors)
#plotting our graphs
for county in selected_counties:
    temp = traffic_counties[traffic_counties['County'] == county]
    temp.plot(x='Year', rot=45,  y=['Back_AADT', 'Ahead_AADT', 'Mean_AADT'], cmap = cmap)
    plt.legend(bbox_to_anchor=(1, 0.5), loc='lower left', prop={'size':15})
    plt.title(county)
    plt.ylabel('count')
    plt.grid(b=False)
    plt.show()

# %% [markdown]
# Above are specific county traffic volumes within our data we chose to analyze considering that more notable shifts in the relationship between air quality and traffic volume will be seen within these counties and other counties alike. We can see that for counties like Los Angeles, San Diego, and Sacramento (potentially others within the data) have a huge dip in the traffic volumes around 2016. This could've been caused by a variety of confounds including but not limited to changes in the United States policies or economy, road closures, increased gas prices, as well as possible error when collecting the data.

# %%
back = traffic_counties[traffic_counties['County'].isin(['San Diego','Sacramento','Mono','Shasta','Santa Cruz'])]
ax = sns.scatterplot(data=back, x='Year', y='Back_AADT', hue='County',palette="mako")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
ax.set_title('Back AADT in Each County from 2008 to 2020')
# Out:
# Text(0.5, 1.0, 'Back AADT in Each County from 2008 to 2020')

# %%
ahead = traffic_counties[traffic_counties['County'].isin(['San Diego','Sacramento','Mono','Shasta','Santa Cruz'])]
ax = sns.scatterplot(data=ahead, x='Year', y='Ahead_AADT', hue='County',palette="mako")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
ax.set_title('Ahead AADT in Each County from 2008 to 2020')
# Out:
# Text(0.5, 1.0, 'Ahead AADT in Each County from 2008 to 2020')

# %% [markdown]
# ## Gasoline Data
#
# ###  Annual Gasoline Sales by City

# %%
#getting the mean
gas_sales["Mean Sales"] = gas_sales[["2011","2012","2013","2014","2015","2016","2017","2018","2019","2020"]].mean(1)

# %% [markdown]
# ## Gasoline Sales throughout California for specific years
# Below are histograms of cities' gas usage per year, with the Y-Label being the amount of cities in that bin, while the X label is the amount of gasoline sold per year by 1,000,000.

# %%
# Histograms for gasoline sales across California
cm = plt.cm.get_cmap('RdYlBu_r')
selected_years = ['2011','2015','2020']
for year in selected_years:
    gas_sales_hist, bins, patches = plt.hist(gas_sales[year], 60, density=True, color="green")
    plt.title('Gasoline Sales ' + year, fontsize= 20)
    plt.xlabel('Amount Sold over ' + year)
    plt.ylabel('Amount of Counties')

    bin_centers = .5*(bins[:-1]+bins[1:])

    col= bin_centers -min(bin_centers)
    col /= max(col)

    for c,p in zip(col,patches):
        plt.setp(p, "facecolor", cm(c))
    plt.show()

# %% [markdown]
# When looking at distributions of gasoline sales for California counties for the years 2011, 2015, and 2020, we notice some counties with large populations and high traffic counts such as Los Angeles and San Diego are clearly outliers. However we also notice that over time those same counties have a decreasing amount of gasoline sold.

# %% [markdown]
# ## Gasoline Sales over time by County

# %%
#setting up our variables
orig_cmap = plt.cm.viridis
colors = orig_cmap(np.linspace(min_val, max_val, n))
cmap = mpl.colors.LinearSegmentedColormap.from_list("mycmap", colors)
#plotting our graphs
for county in selected_counties:
    temp = gas_sales_T
    temp.plot(x = 'Year', rot = 45, y = county, cmap = cmap)
    plt.legend(bbox_to_anchor=(1, 0.5), loc='lower left', prop={'size':15})
    plt.title(county)
    plt.ylabel('gallons per 1000')
    plt.grid(b=False)
    plt.show()

# %% [markdown]
# Above are the Gasoline Sales Data for specific counties within California over the years 2011-2020. As seen above some counties have a drop in gasoline sales around 2013/2014 which could be caused by a variety of confounds similar to the traffic volume data.

# %%
#plotting our graphs
temp = gas_sales_T_capita
temp.plot(x = 'Year', rot = 45, y = gas_sales_T_capita.columns[1:], legend = None)
plt.title('Gasoline sales by County per Capita')
plt.ylabel('gallons per 1000')
plt.grid(b=False)
plt.show()

# %% [markdown]
# As seen above there is a general drop in gasoline sales for all California counties around the year 2014 which could've been caused by various confounds as well as possible errors when collecting the data.

# %%
#setting up the mean
gas_sales_T_capita['Mean'] = gas_sales_T_capita[gas_sales_T_capita.columns[1:]].mean(axis = 1)
#plotting our graphs
temp = gas_sales_T_capita
temp.plot(x = 'Year', rot = 45, y = 'Mean', legend = None)
plt.title('Average Gasoline sales by County per Capita')
plt.ylabel('gallons per 1000')
plt.grid(b=False)
plt.show()

# %% [markdown]
# ## Visualizing Outliers

# %% [markdown]
# To visualize the outliers of our data, we will plot each major Dataset on a boxplot to further understand its distribution. It will be important to note any Outliers to our Data as this can change our final conclusion and discussion.

# %%
fig, ax = plt.subplots(1,3)
fig.set_size_inches(30,8)
fig.suptitle("Outliers for each major Dataset",fontsize=25)

aqi = sns.boxplot(y=aqi_county_CA['Median AQI'], ax=ax[0]).set(title="Median AQI", ylabel="Median AQI per County")
traffic = sns.boxplot(y=traffic_counties['Mean_AADT'],ax=ax[1]).set(title="Mean Traffic AADT", ylabel="Mean AADT per County")
gas = sns.boxplot(y=gas_sales["Mean Sales"],ax=ax[2]).set(title="Average Gas Sales", ylabel="Average Gas Sales per Year")

plt.show()

# %% [markdown]
# ## OLS Attempts
#
# An attempt to do Linear Regression via Max AQI and Traffic Mean AADT

# %%
aqi_traffic = [aqi_county_CA, traffic_counties]

result_aqi_traffic = functools.reduce(lambda left,right: pd.merge(left,right, on=['County',"State","Year"], how='outer'), aqi_traffic).fillna('void')
result_aqi_traffic

aqi_traffic_capita = [aqi_county_CA, traffic_counties_capita]

result_aqi_traffic_capita = functools.reduce(lambda left,right: pd.merge(left,right, on=['County',"State","Year"], how='outer'), aqi_traffic_capita).fillna('void')

# %%
df_aqi_traffic = result_aqi_traffic[["Median AQI", "Mean_AADT"]]
df_aqi_traffic.columns = ["AQI", "Traffic"]

df_aqi_traffic["AQI"] = pd.to_numeric(df_aqi_traffic["AQI"], downcast="float", errors="coerce")
df_aqi_traffic["Traffic"] = pd.to_numeric(df_aqi_traffic["Traffic"], downcast="float", errors="coerce")

print(df_aqi_traffic.dtypes)

x = df_aqi_traffic["AQI"].tolist()
y = df_aqi_traffic["Traffic"].tolist()

ar_x=np.asarray(x)
ar_y=np.asarray(y)

#result = sm.OLS(ar_y,ar_x).fit()
outcome, predictors = patsy.dmatrices("AQI ~ Traffic", df_aqi_traffic, return_type = "dataframe")

mod_log = sm.OLS(outcome,predictors)
res_log = mod_log.fit()

print(res_log.summary())

df_aqi_traffic.head()
# Out:
# AQI        float32
# Traffic    float32
# dtype: object
#                             OLS Regression Results
# ...
# Dep. Variable:                    AQI   R-squared:                       0.155
# Model:                            OLS   Adj. R-squared:                  0.154
# Method:                 Least Squares   F-statistic:                     108.0
# Date:                Mon, 14 Mar 2022   Prob (F-statistic):           2.42e-23
# Time:                        22:06:21   Log-Likelihood:                -2415.9
# No. Observations:                 589   AIC:                             4836.
# Df Residuals:                     587   BIC:                             4845.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# In interpreting the Raw Data Model, our p-value (2.42e-23) is less than .05, our alpha level, which means this could potentially be statistically significant, but our r-squared, which  determins how much variance is able to be captured by the model is .155. This lower value suggests the the model is unable to capture all the variance in our data. This means that this model is not a good fit, since our r-squared is so low, even though our p-value is high. This could be a miscalculation, because we are not well-educated in reading OLS models.

# %%
df_aqi_traffic_capita = result_aqi_traffic_capita[["Median AQI", "Mean_AADT"]]
df_aqi_traffic_capita.columns = ["AQI", "Traffic"]

df_aqi_traffic_capita["AQI"] = pd.to_numeric(df_aqi_traffic_capita["AQI"], downcast="float", errors="coerce")
df_aqi_traffic_capita["Traffic"] = pd.to_numeric(df_aqi_traffic_capita["Traffic"], downcast="float", errors="coerce")

print(df_aqi_traffic_capita.dtypes)

x = df_aqi_traffic_capita["AQI"].tolist()
y = df_aqi_traffic_capita["Traffic"].tolist()

ar_x=np.asarray(x)
ar_y=np.asarray(y)

#result = sm.OLS(ar_y,ar_x).fit()
outcome, predictors = patsy.dmatrices("AQI ~ Traffic", df_aqi_traffic_capita, return_type = "dataframe")

mod_log = sm.OLS(outcome,predictors)
res_log = mod_log.fit()

print(res_log.summary())

df_aqi_traffic_capita.head()
# Out:
# AQI        float32
# Traffic    float32
# dtype: object
#                             OLS Regression Results
# ...
# Dep. Variable:                    AQI   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     7.492
# Date:                Mon, 14 Mar 2022   Prob (F-statistic):            0.00639
# Time:                        22:06:21   Log-Likelihood:                -2462.0
# No. Observations:                 589   AIC:                             4928.
# Df Residuals:                     587   BIC:                             4937.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# In interpreting the Normalized Model, our p-value (.00639) is less than .05, our alpha level, which means this could potentially be statistically significant, but our r-squared, which  determins how much variance is able to be captured by the model is .013. This lower value suggests the the model is unable to capture all the variance in our data. This means that this model is not a good fit, since our r-squared is so low, even though our p-value is high. This could be a miscalculation, because we are not well-educated in reading OLS models.

# %% [markdown]
# ## Scatter Matrix and Depedent Variables

# %%
pd.plotting.scatter_matrix(df_aqi_traffic, alpha=0.2, figsize=(10,10), hist_kwds={"bins":30})
plt.suptitle("Scatter Matrix for AQI and Traffic")
plt.show()

# %% [markdown]
# As seen in the Scatter Matrix above, there are no strong relationships between the two varaibles used. However, this could be a miscalculation, because we are not well-educated in reading Scatter Matrixes.

# %%
pd.plotting.scatter_matrix(df_aqi_traffic_capita, alpha=0.2, figsize=(10,10), hist_kwds={"bins":30})
plt.suptitle("Scatter Matrix for AQI and Traffic per Capita")
plt.show()

# %% [markdown]
# As seen in the Scatter Matrix above, there are no strong relationships between the two varaibles used. However, this could be a miscalculation, because we are not well-educated in reading Scatter Matrixes.

# %% [markdown]
# ### Confounds
# There are a few possible confounding variables in our exploratory data analysis. First regarding the AQI counts, we thought that Max AQI could be a statistic that we may not want to use in the final analysis due to the possibility of there being a large outlier in measured air quality of one region during one day. We want to remove as many sources of error as possible, so taking outliers into consideration is something we will continue to do. Another possible confound is in the initial measuring of the Air Quality. Because we did not control the data gathering process but rather used data that we found online through government air quality monitering websites, we cannot ensure that each air quality measuring station in each county of California took equal steps to be placed in optimal locations, with optimal care. Unfortunately because we cannot see how the raw data was gathered, it is unfortunately difficult to account for this confound. Regardless, we thought it would be apt to discuss the possibility of this influencing our EDA.
#
# As for the traffic data, there are also multiple potential confounds that we thought to be aware of. The first is, like the air quality data, we did not measure the traffic counts ourselves, so we are unable to guarantee that the traffic measurements were collected in each county through optimal means, or more specifically whether the AADT measurements were collected from the most relevant roads to the regional community. This could significantly impact the way we view the traffic counts over our years of data exploration, especially if an important or often used road was left off the measurements. However, like the air quality data, there is little we can do to account for this potential confound, so unfortunately we must take our data as is in this case. Another confound for traffic data we thought of was the possibility of construction or obstructions that block certain roads. We noticed a couple outliers in the traffic data while creating our visual plots, which can be seen in the plots for San Diego and Sacramento county traffic over time. There was a significant drop of traffic counts in both counties in the year 2016, which leads us to believe that there was either an obstruction of the road or an obstruction of the actual traffic measuring procedure that caused what seems to be an outlier. Because it is a line plot, we thought it was appropriate to still include this information in the plot, but we felt that it was important to mention this outlier in our data.
#
# As for the gasoline sales data, we believed there were a few confounding variables that might lead to a skew in the data. Similar to the other datasets, we did not measure gasoline sales throughout cities in California, so we are unable to ensure that the measurements taken were by optimal means, or that the gasoline sales data was collected uniformly throughout each city in the dataset. This could potentially lead to a significant impact in the way that we analyze the gasoline data in regards to the other datasets and potential relationships. Similarly, we also noticed that there were outliers in the data, or more specifically that a couple of cities had substantially high gasoline sales throughout the years , and others had substantially low gasoline sales throughout the years,  as is seen when plotting a histogram for the gasoline sales throughout California for the years 2011, 2015, and 2020. Also we can see that for some cities, more than likely a large populated city, there is a drop in gasoline sales specifically around the year 2014, which we believe could lead to an impact in our analysis as well.

# %% [markdown]
# # Relationships
# As of right now, the relationship between gasoline sales, traveling, and air quality are not that tight knit. It may be possible that we have not completed the full analysis of the counties to get a better idea of what's happening. We only have 5 counties to look over. Another thing that we may have to check out is the locations of the AQI sensors, it could cause a bias in how the data is collected. As well, we need to consider is who's buying the gasoline in each county since some areas like LA took a dip in gasoline sales, but their traffic count barely decreased. Lastly, our inability to correctly read and interpret our results could potentially change the data analysis in whole.

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# **Do we have permission to use this data?**
#
# As all of the data we have collected is open to the public for fair use, our group has permission to use this data and for this purpose. All of our datasets for our variables: Air Quality, COVID-19 Rates, Tax Income, and Job Titles are from Kaggle, EPA and EIA. Which are all open to the public for viewing, education and for use.
#
# **Are there privacy concerns regarding your datasets that you need to deal with, and/or terms of use that you need to comply with?**
#
# The air quality data that will be used for our project was collected by AirNow, which is "A partnership of the U.S. Environmental Protection Agency, National Oceanic and Atmospheric Administration (NOAA), National Park Service, NASA, Centers for Disease Control, and tribal, state, and local air quality agencies"(1). This data is publicly available through government websites and is free from personally identifiable information, which protects us from many privacy concerns that we may otherwise need to be worried about. Given that none of the air quality data was ever associated with an individial, we believe that this would be safe to legally use.
#
# As for the data regarding industries across the state of California, any data we find regarding this will be cleaned and sorted to make sure that any personal identifying information that could associate any individuals with any particular job will be removed and anonymized. We are looking for this data through websites such as Kaggle or Our World in Data and through government websites that provide open-source, free use datasets, so we expect that we shouldn't run into too many complications with privacy, as much of the data has already been released to adhere to data privacy laws.
#
# **Are there potential biases in your dataset(s), in terms of who it composes, and how it was collected, that may be problematic in terms of it allowing for equitable analysis?**
#
# Looking ahead at the kind of datasets we will be using, it is possible that there could exist potential biases. In air quality data for the state of California, it is possible that some areas are underrepresented or misrepresented due to either a) a lack of adequate air quality measurement tools or b) air quality measurement tools being placed in non-ideal locations for a fair assessment of the actual air quality of the local region. Depending on the average wealth and population of the region, there could be a difference in care of how the data was gathered, which may lead to biased results.
#
# For data about industries in California, we will likely use census information or data gathered by a third party associating certain regions with certain industries, so the biases we must be cognizant of are who the data was collected by and for what purpose. We think that census data should be largely free of bias given that the point is simply gather information about the citizenry, but if we are looking into datasets collected by third parties, we must also be aware of why the data was gathered in the first place. If the data was gathered for a biased purpose, such as looking into which industries are "best" in California by an agricultural group, we should be wary of using that data because of the biases that may come with it. Thus, we will look into finding datasets that have data about California regional industries gathered for a non-biased purpose.
#
# **What will we be doing with this data?**
#
# We will be using this data only for the purpose of only our COGS 108 Final assignment. We do not intend to ever use this project for monetary use, this is strictly for educational purposes only.
#
#
#
# 1) https://www.airnow.gov/about-airnow/

# %% [markdown]
# # Conclusion & Discussion

# %% [markdown]
# ## Conclusion of Data Analysis
#
# Our goal of this project was to describe the potential correlation between California Air Quality and the COVID-19 pandemic with the subsequent change in car traffic volume.  We hypothesized that the pandemic had an overall good effect on Air Quality in California due to a decrease in car traffic volume. Through our exploratory data analysis, we have come to reject our original hypothesis.
#
# We used Air Quality data from 2010-2021 across all counties in California, but we picked a few counties that represented different regions to focus on. These counties included Los Angeles, San Diego, Shasta, Santa Cruz, Mariposa, and Sacramento. When looking at the overall trends in the changes of AQI in these counties, we could not see a significant differences from year-to-year measures. We also could not identify meaningful changes in the relationship between traffic volume and air quality, especially during the time period of the COVID-19 pandemic (2020-2021).
#
# We also investigated a potential relationship between gasoline sales in California with changes in air quality, but once again were unable to find a significant relationship between the two variables. Although there was a noticable drop in gasoline sales during the time period of the COVID-19 pandemic, there was no effect on the relationship with air quality according to our data. In conclusion, with the data that we were able to gather for the air quality, traffic volume, and gasoline sales in California, we were unable to find any statistically significant relationships between these variables.
#
#
# ## Discussion of Data Analysis
#
# We first decided to create a multitude of graphs and illustrations to help us and the reader understand the Datasets. This allowed us to see a better picture of how the different Datasets related to one another. Starting with our Air Quality (Measured by AQI), we used several graphs and included a Heat Map as well. The results showed that there was definitely an outlier when it came to some Southern California Counties. Specifically Los Angeles, which had a worsened AQI compared to the other chosen Counties. In terms of Traffic Volumes (Measured by AADT), we also used several graphs and included another two Heat Maps to help illustrate the effects. Interestingly, we noted that several Counties had a huge fall in Traffic Volumes in the year 2016. Our group wanted to investigate this anomoly further, but we were not able to find any information to conclude our findings. Lastly, in terms of Gasoline Sales, we used several graphs and looked at individual Counties to further provide a big picture of what happened throughout our chosen years. It again peaked out interest, when we found a large fall in Gasoline Sales around the year of 2014. We also tried to investigate this further, but were unable to find anything.
#
# In terms of our further analysis of our Data, we decided to find the outliers of each Dataset and attempt to do OLS (Ordinary least squares). When it came to our outliers, we found the Data quite intruiging. While Median AQI had hardly any outliers, the other two Data did. Traffic Mean AADT showed many outliers, as did Gasoline Mean Sales, this could be because of places like Los Angeles, and San Francisco, which have a large amount of traffic and gasoline sales per year. It was just interesting to see, and helped us to understand the relationships given. As for OLS, we attempted to look into the relationship between Median AQI and Traffic Mean AADT. We first used the Raw Data, and then Normalized the Data in the second OLS attempt. Both showed a smaller p-Value than our Alpha level, which is good. However, our r-squared were both too low and indicated both models were not a good fit. When it came to both of our Scatter Matrixes (one of Raw Data, one of Normalized Data), we did not find a signficiant relationship between AQI and Traffic.
#
# Although we rejected our initial hypothesis that there was a positive relationship between the air quality and decrease in traffic volume due to the COVID-19 pandemic, this does not necessarily indicate that no such relationship actually exists. We think that the reason we were unable to establish a statistically significant relationship between the two variables of investigation was due to the limitations we had with the data. As discussed above, there are multiple confounding variables which we believe contribute to us not being able to draw a clear conclusion that reliably demonstrates a positive relationship. If we were able to continue our work in investigating this topic, we would take greater steps to find more extensive and detailed data about the air quality measures across California. We would also be highly interested to see what conclusions other researchers and analysts are able to draw in the future, with air quality data that is more up-to-date and reflective of the actual time period of the COVID-19 pandemic. As the world returns slowly to a sense of normalcy, we feel that this topic of our impact on the environment around us is important to recognize and we wish to see further attention dedicated towards this field.

# %% [markdown]
# # Team Contributions

# %% [markdown]
# Who did what (We all worked on each Checkpoint):
# - Ava Hamedi - EDA Graphs, Background Information, Dataset Collection
# - Marc Mendoza - Background Information, Gasoline Data, EDA Confounding Variables
# - Jonathan Park - Data Cleaning, Ethics and Privacy, Finishing Conclusion and Discussion
# - Daniel Renteria - Data Cleaning, Ethics and Privacy, EDA Relationships
# - Siena Rivera - EDA Graphs, Dataset Collection, OLS and Scatter Matrix
